# %%
import pandas as pd
import csv
import re
import nltk
import numpy as np

# %%
lemm = nltk.stem.WordNetLemmatizer()

contractions = { 
"ain't": "am not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he had",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how is",
"I'd": "I had",
"I'd've": "I would have",
"I'll": "I will",
"I'll've": "I will have",
"I'm": "I am",
"I've": "I have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she had",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so is",
"that'd": "that had",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there had",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they had",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we had",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what'll've": "what will have",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who'll've": "who will have",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you had",
"you'd've": "you would have",
"you'll": "you will",
"you'll've": "you will have",
"you're": "you are",
"you've": "you have"
}

# %%
def clean_text(text):
    text = text.lower()
    text = text.split()
    new_text = []
    for word in text:
        if word in contractions:
            new_text.append(contractions[word])
        else:
            new_text.append(word)
    text = " ".join(new_text)

    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)
    text = re.sub(r'\<a href', ' ', text)
    text = re.sub(r'&amp;', '', text) 
    text = re.sub(r'[_"\-;%()|+&=*%.,!?:#$@\[\]/]', ' ', text)
    text = re.sub(r'<br />', ' ', text)
    text = re.sub(r'\'', ' ', text)
    text = re.sub('[^a-zA-Z0-9]', " ",re.sub('&lt;|&gt;|&amp;|&quot;'," ",text))
    text = text.replace('  ',' ').lstrip().rstrip()

    text =  nltk.WordPunctTokenizer().tokenize(text)
    for k in range(len(text)):
        text[k] = lemm.lemmatize(text[k])

    text = " ".join(text)
    return text

# %%
dff=pd.DataFrame(pd.read_csv('../../dataset/fakenews_dataset/Fake.csv'))
dft=pd.DataFrame(pd.read_csv('../../dataset/fakenews_dataset/True.csv'))

# %%
dff = dff.drop(columns = ['subject', 'date'])
# dff = dff.head(5000)

# %%
dft = dft.drop(columns = ['subject', 'date'])
# dft = dft.head(5000)

# %%
final_df = pd.DataFrame()

# %%
# count = 0
for x in dff.index:
    title = clean_text(dff['title'][x])
    text = clean_text(dff['text'][x])
    value = 0
    if len(title) > 0 and len(text) > 0:
        dict1 = {'title': title, 'text': text, 'value': value}
        final_df = final_df.append(dict1, ignore_index=True)
    #     count += 1
    # if count == 10000:
    #     break

# %%
# count = 0
for x in dft.index:
    title = clean_text(dft['title'][x])
    text = clean_text(dft['text'][x])
    value = 1
    if len(title) > 0 and len(text) > 0:
        dict1 = {'title': title, 'text': text, 'value': value}
        final_df = final_df.append(dict1, ignore_index=True)
    #     count += 1
    # if count == 10000:
    #     break

# %%
final_df = final_df.reindex(np.random.permutation(final_df.index))

# %%
final_df.to_csv('../../dataset/fakenews_dataset/processed44k.csv')

# %%
final_df
# Out:
#                                                     text  \
# 34348  kiev reuters ukraine s state security service ...
# 42853  moscow reuters the kremlin said on thursday au...
# 21131  she wa an unethical dishonest lawyer she consp...
# 21307  the event in charlottesville have shaken the a...
# 32406  washington reuters president barack obama on f...
# ...                                                  ...
# 9634   when people say what happens in la vega stay i...
# 38766  beirut reuters with islamic state near defeat ...
# 40799  jordan river west bank reuters thousand of isr...
# 6110   a politico report an almost neck and neck race...
# 16275  if i found out my college age daughter wa atte...
#
#                                                    title  value
# 34348  ukraine detains suspected russian spy in premi...    1.0
# 42853  russia hunting bomb hoaxer say targeted by tel...    1.0
# 21131  hillary clinton we all know she s deceitful an...    0.0
# 21307  interview did the alt right die in charlottesv...    0.0
# 32406  obama to deliver statement on the economy whit...    1.0
# ...                                                  ...    ...
# 9634   what the heck is going on in la vega video pro...    0.0
# 38766  assad set sight on kurdish area risking new sy...    1.0
# 40799  woman march through desert for israeli palesti...    1.0
# 6110   the los angeles time endorses hillary clinton ...    0.0
# 16275  flashback bernie sander socialist democrat par...    0.0
#
# [44171 rows x 3 columns]

# %%
df=pd.DataFrame(pd.read_csv('../../dataset/fakenews_dataset/processed5k.csv'))

# %%
df
# Out:
#       Unnamed: 0                                               text  \
# 0           3775  washington reuters u s president donald trump ...
# 1           2804  brussels reuters u s secretary of state rex ti...
# 2            925  the current occupant of the white house travel...
# 3            546  the republican jewish coalition finally caught...
# 4           3713  washington reuters president donald trump said...
# ...          ...                                                ...
# 4995        1843  we all love seeing alec baldwin portray donald...
# 4996        4179  new york reuters the united state britain and ...
# 4997         293  the most punchable alt right nazi on the inter...
# 4998        1880  back in february donald trump decided he wa go...
# 4999         688  amateur president donald trump signed wa force...
#
#                                                   title  value
# 0     trump say puerto ricans are wonderful have unm...    1.0
# 1     you re wrong tillerson say of report he will b...    1.0
# 2     trump in poland everyone in the u s is now get...    0.0
# 3     the republican jewish coalition love trump so ...    0.0
# 4     trump say he belief cuba responsible for attac...    1.0
# ...                                                 ...    ...
# 4995  o reilly and trump bond over sexual harassment...    0.0
# 4996  anti assad nation say no to syria reconstructi...    1.0
# 4997  gop senator just smacked down the most punchab...    0.0
# 4998  watch arnold schwarzenegger just burned trump ...    0.0
# 4999  trump humiliated by being forced to sign russi...    0.0
#
# [5000 rows x 4 columns]
